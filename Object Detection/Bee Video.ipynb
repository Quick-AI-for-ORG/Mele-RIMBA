# %%
import os
import time
from ultralytics import YOLO
import cv2
import numpy as np

# %%
vidPath = 'Test/VID_20250116_115528.mp4'
vidoutpath ='{}_out.mp4'.format(vidPath)
cap = cv2.VideoCapture(vidPath)
ret, frame = cap.read()
h,w,_ = frame.shape
out = cv2.VideoWriter(vidoutpath,cv2.VideoWriter_fourcc(*'MP4V'), int(cap.get(cv2.CAP_PROP_FPS)),(w,h))

# %%
modelPath = 'train41/weights/last.pt'
model = YOLO(modelPath)
threshold = 0.3

# %%
while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            res = f"{score:.2f} {results.names[int(class_id)].upper()}"
            cv2.putText(frame, res, (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 (no detections), 19.0ms
# Speed: 2.8ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.6ms
# Speed: 1.6ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 18.0ms
# Speed: 9.4ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 11.7ms
# Speed: 7.1ms preprocess, 11.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 14.3ms
# Speed: 2.4ms preprocess, 14.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 21.7ms
# Speed: 0.0ms preprocess, 21.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 (no detections), 7.3ms
# Speed: 4.8ms preprocess, 7.3ms inference, 6.8ms postprocess per image at shape (1, 3, 640, 384)
#
# ...
