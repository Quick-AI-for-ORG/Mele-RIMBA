# %%
import pandas as pd
from pycaret.time_series import TSForecastingExperiment

# %% [markdown]
# ### Load and preprocess data

# %%
def loadAndPreprocessData(filePath):
    data = pd.read_csv(filePath)
    data['Date_Time'] = pd.to_datetime(data['Date_Time'])
    data['Date'] = data['Date_Time'].dt.date
    dailyData = data.groupby('Date').agg({'Temperature_C': 'mean'}).reset_index()
    dailyData['Date'] = pd.to_datetime(dailyData['Date'])
    dailyData = dailyData.set_index('Date').asfreq('D')
    dailyData = dailyData.interpolate(method='time')
    return dailyData

# %% [markdown]
# ### Splitting the data into training & testing

# %%
def splitData(data, splitRatio=0.8):
    splitIndex = int(len(data) * splitRatio)
    trainData = data.iloc[:splitIndex].copy()
    testData = data.iloc[splitIndex:].copy()
    print(f"Training set shape: {trainData.shape}")
    print(f"Test set shape: {testData.shape}")
    return trainData, testData

# %% [markdown]
# ### Pycaret Setup

# %%
def setupExperiment(trainData, targetColumn, sessionId=123):
    experiment = TSForecastingExperiment()
    experiment.setup(
        data=trainData,
        target=targetColumn,
        numeric_imputation_target='mean',
        session_id=sessionId
    )
    return experiment

# %% [markdown]
# ### Comparing models & Extrcting best model

# %%
def trainBestModel(experiment):
    bestModel = experiment.compare_models(sort='MAE')
    return bestModel

# %%
dailyData = loadAndPreprocessData('weather_data.csv')

trainData, testData = splitData(dailyData)

exp = setupExperiment(trainData, targetColumn='Temperature_C')

bestModel = trainBestModel(exp)
# Out:
# Training set shape: (111, 1)
# Test set shape: (28, 1)
# <style type="text/css">
# #T_ccc95_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ccc95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ccc95_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ccc95_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccc95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ccc95_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_ccc95_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ccc95_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ccc95_row1_col1" class="data row1 col1" >Temperature_C</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ccc95_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_ccc95_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ccc95_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_ccc95_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ccc95_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_ccc95_row4_col1" class="data row4 col1" >(111, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ccc95_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_ccc95_row5_col1" class="data row5 col1" >(111, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ccc95_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_ccc95_row6_col1" class="data row6 col1" >(110, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ccc95_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_ccc95_row7_col1" class="data row7 col1" >(1, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ccc95_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_ccc95_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ccc95_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_ccc95_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ccc95_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_ccc95_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ccc95_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_ccc95_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ccc95_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_ccc95_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ccc95_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_ccc95_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ccc95_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_ccc95_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ccc95_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_ccc95_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ccc95_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_ccc95_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ccc95_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_ccc95_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ccc95_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_ccc95_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ccc95_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_ccc95_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ccc95_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_ccc95_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ccc95_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_ccc95_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ccc95_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_ccc95_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_ccc95_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_ccc95_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_ccc95_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_ccc95_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_ccc95_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_ccc95_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_ccc95_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_ccc95_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_ccc95_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_ccc95_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_ccc95_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_ccc95_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_ccc95_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_ccc95_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ccc95_level0_row30" class="row_heading level0 row30" >30</t
# <style type="text/css">
# #T_19c73 th {
#   text-align: left;
# }
# #T_19c73_row0_col0, #T_19c73_row1_col0, #T_19c73_row1_col1, #T_19c73_row1_col2, #T_19c73_row1_col3, #T_19c73_row1_col4, #T_19c73_row1_col5, #T_19c73_row1_col6, #T_19c73_row2_col0, #T_19c73_row2_col1, #T_19c73_row2_col2, #T_19c73_row2_col3, #T_19c73_row2_col4, #T_19c73_row2_col5, #T_19c73_row2_col6, #T_19c73_row3_col0, #T_19c73_row3_col1, #T_19c73_row3_col2, #T_19c73_row3_col3, #T_19c73_row3_col4, #T_19c73_row3_col5, #T_19c73_row3_col6, #T_19c73_row4_col0, #T_19c73_row4_col1, #T_19c73_row4_col2, #T_19c73_row4_col3, #T_19c73_row4_col4, #T_19c73_row4_col5, #T_19c73_row4_col6, #T_19c73_row5_col0, #T_19c73_row5_col1, #T_19c73_row5_col2, #T_19c73_row5_col3, #T_19c73_row5_col4, #T_19c73_row5_col5, #T_19c73_row5_col6, #T_19c73_row6_col0, #T_19c73_row6_col1, #T_19c73_row6_col2, #T_19c73_row6_col3, #T_19c73_row6_col4, #T_19c73_row6_col5, #T_19c73_row6_col6, #T_19c73_row7_col0, #T_19c73_row7_col1, #T_19c73_row7_col2, #T_19c73_row7_col3, #T_19c73_row7_col4, #T_19c73_row7_col5, #T_19c73_row7_col6, #T_19c73_row8_col0, #T_19c73_row8_col1, #T_19c73_row8_col2, #T_19c73_row8_col3, #T_19c73_row8_col4, #T_19c73_row8_col5, #T_19c73_row8_col6, #T_19c73_row9_col0, #T_19c73_row9_col1, #T_19c73_row9_col2, #T_19c73_row9_col3, #T_19c73_row9_col4, #T_19c73_row9_col5, #T_19c73_row9_col6, #T_19c73_row10_col0, #T_19c73_row10_col1, #T_19c73_row10_col2, #T_19c73_row10_col3, #T_19c73_row10_col4, #T_19c73_row10_col5, #T_19c73_row10_col6, #T_19c73_row11_col0, #T_19c73_row11_col1, #T_19c73_row11_col2, #T_19c73_row11_col3, #T_19c73_row11_col4, #T_19c73_row11_col5, #T_19c73_row11_col6, #T_19c73_row12_col0, #T_19c73_row12_col1, #T_19c73_row12_col2, #T_19c73_row12_col3, #T_19c73_row12_col4, #T_19c73_row12_col5, #T_19c73_row12_col6, #T_19c73_row13_col0, #T_19c73_row13_col1, #T_19c73_row13_col2, #T_19c73_row13_col3, #T_19c73_row13_col4, #T_19c73_row13_col5, #T_19c73_row13_col6, #T_19c73_row14_col0, #T_19c73_row14_col1, #T_19c73_row14_col2, #T_19c73_row14_col3, #T_19c73_row14_col4, #T_19c73_row14_col5, #T_19c73_row14_col6, #T_19c73_row15_col0, #T_19c73_row15_col1, #T_19c73_row15_col2, #T_19c73_row15_col3, #T_19c73_row15_col4, #T_19c73_row15_col5, #T_19c73_row15_col6, #T_19c73_row16_col0, #T_19c73_row16_col1, #T_19c73_row16_col2, #T_19c73_row16_col3, #T_19c73_row16_col4, #T_19c73_row16_col5, #T_19c73_row16_col6, #T_19c73_row17_col0, #T_19c73_row17_col1, #T_19c73_row17_col2, #T_19c73_row17_col3, #T_19c73_row17_col4, #T_19c73_row17_col5, #T_19c73_row17_col6, #T_19c73_row18_col0, #T_19c73_row18_col1, #T_19c73_row18_col2, #T_19c73_row18_col3, #T_19c73_row18_col4, #T_19c73_row18_col5, #T_19c73_row18_col6, #T_19c73_row19_col0, #T_19c73_row19_col1, #T_19c73_row19_col2, #T_19c73_row19_col3, #T_19c73_row19_col4, #T_19c73_row19_col5, #T_19c73_row19_col6, #T_19c73_row20_col0, #T_19c73_row20_col1, #T_19c73_row20_col2, #T_19c73_row20_col3, #T_19c73_row20_col4, #T_19c73_row20_col5, #T_19c73_row20_col6, #T_19c73_row21_col0, #T_19c73_row21_col1, #T_19c73_row21_col2, #T_19c73_row21_col3, #T_19c73_row21_col4, #T_19c73_row21_col5, #T_19c73_row21_col6, #T_19c73_row22_col0, #T_19c73_row22_col1, #T_19c73_row22_col2, #T_19c73_row22_col3, #T_19c73_row22_col4, #T_19c73_row22_col5, #T_19c73_row22_col6, #T_19c73_row23_col0, #T_19c73_row23_col1, #T_19c73_row23_col2, #T_19c73_row23_col3, #T_19c73_row23_col4, #T_19c73_row23_col5, #T_19c73_row23_col6, #T_19c73_row24_col0, #T_19c73_row24_col1, #T_19c73_row24_col2, #T_19c73_row24_col3, #T_19c73_row24_col4, #T_19c73_row24_col5, #T_19c73_row24_col6, #T_19c73_row25_col0, #T_19c73_row25_col1, #T_19c73_row25_col2, #T_19c73_row25_col3, #T_19c73_row25_col4, #T_19c73_row25_col5, #T_19c73_row25_col6 {
#   text-align: left;
# }
# #T_19c73_row0_col1, #T_19c73_row0_col2, #T_19c73_row0_col3, #T_19c73_row0_col4, #T_19c73_row0_col5, #T_19c73_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_19c73_row0_col7, #T_19c73_row1_col7, #T_19c73_row2_col7, #T_19c73_row3_col7, #T_19c73_row5_col7, #T_19c73_row6_col7, #T_19c73_row7_col7, #T_19c73_row8_col7, #T_19c73_row9_col7, #T_19c73_row10_col7, #T_19c73_row11_col7, #T_19c73_row12_col7, #T_19c73_row13_col7, #T_19c73_row14_col7, #T_19c73_row15_col7, #T_19c73_row16_col7, #T_19c73_row17_col7, #T_19c73_row18_col7, #T_19c73_row19_col7, #T_19c73_row20_col7, #T_19c73_row21_col7, #T_19c73_row22_col7, #T_19c73_row23_col7, #T_19c73_row24_col7, #T_19c73_row25_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_19c73_row4_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_19c73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19c73_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_19c73_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_19c73_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_19c73_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_19c73_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_19c73_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_19c73_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_19c73_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19c73_level0_row0" class="row_heading level0 row0" >arima</th>
#       <td id="T_19c73_row0_col0" class="data row0 col0" >ARIMA</td>
#       <td id="T_19c73_row0_col1" class="data row0 col1" >0.0486</td>
#       <td id="T_19c73_row0_col2" class="data row0 col2" >0.0400</td>
#       <td id="T_19c73_row0_col3" class="data row0 col3" >0.0112</td>
#       <td id="T_19c73_row0_col4" class="data row0 col4" >0.0112</td>
#       <td id="T_19c73_row0_col5" class="data row0 col5" >0.0008</td>
#       <td id="T_19c73_row0_col6" class="data row0 col6" >0.0008</td>
#       <td id="T_19c73_row0_col7" class="data row0 col7" >0.1900</td>
#     </tr>
#     <tr>
#       <th id="T_19c73_level0_row1" class="row_heading level0 row1" >naive</th>
#       <td id="T_19c73_row1_col0" class="data row1 col0" >Naive Forecaster</td>
#       <td id="T_19c73_row1_col1" class="data row1 col1" >0.4943</td>
#       <td id="T_19c73_row1_col2" class="data row1 col2" >0.4064</td>
#       <td id="T_19c73_row1_col3" class="data row1 col3" >0.1142</td>
#       <td id="T_19c73_row1_col4" class="data row1 col4" >0.1142</td>
#       <td id="T_19c73_row1_col5" class="data row1 col5" >0.0077</td>
#       <td id="T_19c73_row1_col6" class="data row1 col6" >0.0076</td>
#       <td id="T_19c73_row1_col7" class="data row1 col7" >3.6067</td>
#     </tr>
#     <tr>
#       <th id="T_19c73_level0_row2" class="row_heading level0 row2" >et_cds_dt</th>
#       <td id="T_19c73_row2_col0" class="data row2 col0" >Extra Trees w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_19c73_row2_col1" class="data row2 col1" >0.6543</td>
#       <td id="T_19c73_row2_col2" class="data row2 col2" >0.5375</td>
#       <td id="T_19c73_row2_col3" class="data row2 col3" >0.1505</td>
#       <td id="T_19c73_row2_col4" class="data row2 col4" >0.1505</td>
#       <td id="T_19c73_row2_col5" class="data row2 col5" >0.0102</td>
#       <td id="T_19c73_row2_col6" class="data row2 col6" >0.0100</td>
#       <td id="T_19c73_row2_col7" class="data row2 col7" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_19c73_level0_row3" class="row_heading level0 row3" >grand_means</th>
#       <td id="T_19c73_row3_col0" class="data row3 col0" >Grand Means Forecaster</td>
#       <td id="T_19c73_row3_col1" class="data row3 col1" >0.7575</td>
#       <td id="T_19c73_row3_col2" class="data row3 col2" >0.6228</td>
#       <td id="T_19c73_row3_col3" class="data row3 col3" >0.1751</td>
#       <td id="T_19c73_row3_col4" class="data row3 col4" >0.1751</td>
#       <td id="T_19c73_row3_col5" class="data row3 col5" >0.0117</td>
#       <td id="T_19c73_row3_col6" class="data row3 col6" >0.0118</td>
#       <td id="T_19c73_row3_col7" class="data row3 col7" >2.2067</td>
#     </tr>
#     <tr>
